# %%
# 1. Importar librerías
# Este bloque importa todas las librerías necesarias para trabajar con datos, crear modelos y graficar.

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.model_selection import train_test_split

# %%
# 2. Cargar datos (para Google Colab)
from google.colab import files
uploaded = files.upload()

name = list(uploaded.keys())[0]
df = pd.read_csv(name)
# Out:
#      <input type="file" id="files-1c03b4a0-a773-4c32-80c0-8fbcfc920b27" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-1c03b4a0-a773-4c32-80c0-8fbcfc920b27">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# Este bloque establece una semilla para que los resultados del modelo siempre sean iguales si se repite.

np.random.seed(666)

# %%
# Este bloque muestra las primeras filas del dataset y los nombres de las columnas para entender qué variables hay.

print(data.head())
print(data.columns)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-728933af01fe> in <cell line: 0>()
#       1 # Este bloque muestra las primeras filas del dataset y los nombres de las columnas para entender qué variables hay.
#       2
# ----> 3 print(data.head())
#       4 print(data.columns)
#
# NameError: name 'data' is not defined

# %%
# 3. Definir X e y (Regresión Lineal Simple)
# Aquí se definen las variables: X es la predictora (MatchAssists), y es lo que queremos predecir (MatchKills).

X = data[['MatchAssists']]  # Variable independiente
y = data['MatchKills']      # Variable dependiente

# %%
# 4. Dividir en entrenamiento y prueba
# Se dividen los datos en entrenamiento (80%) y prueba (20%) para evaluar cómo generaliza el modelo.

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=666)

print(f"Entrenamiento: {len(X_train)} datos")
print(f"Prueba: {len(X_test)} datos")
# Out:
# Entrenamiento: 23674 datos
# Prueba: 5919 datos

# %%
# 5. Crear el modelo
# Se crea el modelo de regresión lineal simple que será entrenado con los datos.

modelo_rls = LinearRegression()

# %%
# 6. Entrenar el modelo
# Se entrena el modelo con los datos de entrenamiento para que aprenda la relación entre asistencias y kills.

modelo_rls.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
# 7. Predecir
# Se generan predicciones usando los datos de prueba, es decir, el modelo intenta "adivinar" los kills.

y_pred = modelo_rls.predict(X_test)

# %%
# 7b. Predicción para valor puntual
# Se predice cuántos kills haría un jugador con exactamente 2 asistencias.

pred_2 = modelo_rls.predict([[2]])
print(f"Predicción para MatchAssists = 2: {pred_2[0]:.2f}")
# Out:
# Predicción para MatchAssists = 2: 1.04
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
# 8. Evaluar el modelo
# Se calculan métricas de evaluación: el error (MSE) y qué tan bien explica el modelo los datos (R²).

mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)
print('Error cuadrático medio (MSE):', mse)
print('Coeficiente de determinación (R2):', r2)
# Out:
# Error cuadrático medio (MSE): 0.7180699523304208
# Coeficiente de determinación (R2): 0.28112243194754505

# %%
# 9. Visualizar resultados
# Se grafica la relación entre asistencias y kills, con los puntos reales y la línea del modelo.

plt.scatter(X_test, y_test, color='blue', label='Datos reales')
plt.plot(X_test, y_pred, color='red', linewidth=2, label='Línea de regresión')
plt.xlabel('MatchAssists')
plt.ylabel('MatchKills')
plt.title('Regresión Lineal Simple')
plt.legend()
plt.show()

# %% [markdown]
# 📊 Resultados del modelo:
# 📉 Error cuadrático medio (MSE): 0.726
#
# 📈 Coeficiente de determinación (R²): 0.282
#
# 🧮 Pendiente (coeficiente): 0.522
#
# 📍 Intercepto (ordenada al origen): -0.0051

# %% [markdown]
# Por cada asistencia (MatchAssists) adicional, el modelo predice un aumento promedio de 0.522 en muertes (MatchKills), aunque el poder explicativo es moderado-bajo (R² = 0.28).

# %% [markdown]
# ✅ Conclusión del Modelo de Regresión Lineal Simple
#
# El modelo de regresión lineal simple fue entrenado para predecir la cantidad de muertes (MatchKills) que un jugador puede alcanzar en función del número de asistencias (MatchAssists) durante una partida.
#
# Los resultados muestran que existe una relación positiva entre ambas variables:
#
# por cada asistencia adicional, el modelo estima un aumento promedio de aproximadamente X muertes (valor exacto mostrado en los coeficientes del modelo).
#
# Sin embargo, el poder explicativo del modelo es limitado, con un coeficiente de determinación R² ≈ 0.28.
# Esto significa que solo el 28% de la variabilidad en las muertes puede explicarse por las asistencias. El resto depende de otras variables no consideradas en este modelo (por ejemplo: armas, tiempo vivo, estrategia, etc.).
#
# 🧠 Interpretación final:
#
# Este modelo es útil como una primera aproximación explicativa, fácil de interpretar.
#
# No es ideal para predicciones precisas, pero sirve para mostrar una tendencia general.
#
# Es recomendable avanzar a modelos más complejos (como regresión múltiple o Random Forest) para mejorar la capacidad predictiva.
